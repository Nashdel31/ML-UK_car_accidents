# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2012_to_2014.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2009_to_2011.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2005_to_2007.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accident_coords_update.ipynb
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/ukTrafficAADF.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/Areas.shp
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/Local_Authority_Districts_Dec_2016.geojson

# %%
dataset1=pd.read_csv('/kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2005_to_2007.csv')
dataset2=pd.read_csv('/kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2009_to_2011.csv')
dataset3=pd.read_csv('/kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2012_to_2014.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dataset1 = pd.concat([dataset1,dataset2,dataset3],ignore_index=True)
dataset1.info()
#dataset2.info()
#dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Accident_Index                               1504150 non-null  object
#  1   Location_Easting_OSGR                        1504049 non-null  float64
#  2   Location_Northing_OSGR                       1504049 non-null  float64
#  3   Longitude                                    1504049 non-null  float64
#  4   Latitude                                     1504049 non-null  float64
#  5   Police_Force                                 1504150 non-null  int64
#  6   Accident_Severity                            1504150 non-null  int64
#  7   Number_of_Vehicles                           1504150 non-null  int64
#  8   Number_of_Casualties                         1504150 non-null  int64
#  9   Date                                         1504150 non-null  object
#  10  Day_of_Week                                  1504150 non-null  int64
#  11  Time                                         1504033 non-null  object
#  12  Local_Authority_(District)                   1504150 non-null  int64
#  13  Local_Authority_(Highway)                    1504150 non-null  object
#  14  1st_Road_Class                               1504150 non-null  int64
#  15  1st_Road_Number                              1504150 non-null  int64
#  16  Road_Type                                    1504150 non-null  object
#  17  Speed_limit                                  1504150 non-null  int64
#  18  Junction_Detail                              0 non-null        float64
#  19  Junction_Control                             901315 non-null   object
#  20  2nd_Road_Class                               1504150 non-null  int64
#  21  2nd_Road_Number                              1504150 non-null  int64
#  22  Pedestrian_Crossing-Human_Control            1504133 non-null  object
#  23  Pedestrian_Crossing-Physical_Facilities      1504116 non-null  object
#  24  Light_Conditions                             1504150 non-null  object
#  25  Weather_Conditions                           1504024 non-null  object
#  26  Road_Surface_Conditions                      1502192 non-null  object
#  27  Special_Conditions_at_Site                   1504135 non-null  object
#  28  Carriageway_Hazards                          1504121 non-null  object
#  29  Urban_or_Rural_Area                          1504150 non-null  int64
#  30  Did_Police_Officer_Attend_Scene_of_Accident  1501228 non-null  object
#  31  LSOA_of_Accident_Location                    1395912 non-null  object
#  32  Year                                         1504150 non-null  int64
# dtypes: float64(5), int64(13), object(15)
# memory usage: 378.7+ MB

# %%
df1=dataset1.drop(['Accident_Index',
                   'Local_Authority_(District)',
                   'Local_Authority_(Highway)',
                   '1st_Road_Number',
                   'Junction_Detail',
                   '2nd_Road_Number',
                   'Year',
                   'Location_Easting_OSGR',
                   'Location_Northing_OSGR',
                   'Longitude',
                   'Latitude',
                   'LSOA_of_Accident_Location'
                  ],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1504150 non-null  int64
#  1   Accident_Severity                            1504150 non-null  int64
#  2   Number_of_Vehicles                           1504150 non-null  int64
#  3   Number_of_Casualties                         1504150 non-null  int64
#  4   Date                                         1504150 non-null  object
#  5   Day_of_Week                                  1504150 non-null  int64
#  6   Time                                         1504033 non-null  object
#  7   1st_Road_Class                               1504150 non-null  int64
#  8   Road_Type                                    1504150 non-null  object
#  9   Speed_limit                                  1504150 non-null  int64
#  10  Junction_Control                             901315 non-null   object
#  11  2nd_Road_Class                               1504150 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1504133 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1504116 non-null  object
#  14  Light_Conditions                             1504150 non-null  object
#  15  Weather_Conditions                           1504024 non-null  object
#  16  Road_Surface_Conditions                      1502192 non-null  object
#  17  Special_Conditions_at_Site                   1504135 non-null  object
#  18  Carriageway_Hazards                          1504121 non-null  object
#  19  Urban_or_Rural_Area                          1504150 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1501228 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 241.0+ MB

# %%
# en faisant la soustraction des 'True' de verif2 et verif3, on obtient le nbr de mesure où 
# il y a 2nd_Road_Class != -1 (donc il y a une route secondaire) mais 
# il n'y a pas de descriptif du control de l'intersection.
#
# De plus, le résultat de cette soustraction est positif donc
# toutes les lignes avec 2nd_Road_Class == -1 correspondent bien à Junction_Control == Null

# %%
#True si il y a une 2nd_Road mais pas de description du control de l'intersection
#verif4=df1.apply(lambda x:True if x['2nd_Road_Class'] != -1 and x['Junction_Control']!='Authorised person' and x['Junction_Control']!='Giveway or uncontrolled' and x['Junction_Control']!='Automatic traffic signal' and x['Junction_Control']!='Stop Sign' else False, axis=1)
#verif4.value_counts()

# %%
df1['verif']=df1.apply(lambda x:True if x['2nd_Road_Class'] != -1 and x['Junction_Control']!='Authorised person' and x['Junction_Control']!='Giveway or uncontrolled' and x['Junction_Control']!='Automatic traffic signal' and x['Junction_Control']!='Stop Sign' else False, axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1504150 non-null  int64
#  1   Accident_Severity                            1504150 non-null  int64
#  2   Number_of_Vehicles                           1504150 non-null  int64
#  3   Number_of_Casualties                         1504150 non-null  int64
#  4   Date                                         1504150 non-null  object
#  5   Day_of_Week                                  1504150 non-null  int64
#  6   Time                                         1504033 non-null  object
#  7   1st_Road_Class                               1504150 non-null  int64
#  8   Road_Type                                    1504150 non-null  object
#  9   Speed_limit                                  1504150 non-null  int64
#  10  Junction_Control                             901315 non-null   object
#  11  2nd_Road_Class                               1504150 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1504133 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1504116 non-null  object
#  14  Light_Conditions                             1504150 non-null  object
#  15  Weather_Conditions                           1504024 non-null  object
#  16  Road_Surface_Conditions                      1502192 non-null  object
#  17  Special_Conditions_at_Site                   1504135 non-null  object
#  18  Carriageway_Hazards                          1504121 non-null  object
#  19  Urban_or_Rural_Area                          1504150 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1501228 non-null  object
#  21  verif                                        1504150 non-null  bool
# dtypes: bool(1), int64(9), object(12)
# memory usage: 242.4+ MB

# %%
df1['Junction_Control'].value_counts()
# Out:
# Giveway or uncontrolled     733940
# Automatic traffic signal    155717
# Stop Sign                     9179
# Authorised person             2479
# Name: Junction_Control, dtype: int64

# %%
df1.drop(df1[df1['verif']==True].index,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1503317 entries, 0 to 1504149
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1503317 non-null  int64
#  1   Accident_Severity                            1503317 non-null  int64
#  2   Number_of_Vehicles                           1503317 non-null  int64
#  3   Number_of_Casualties                         1503317 non-null  int64
#  4   Date                                         1503317 non-null  object
#  5   Day_of_Week                                  1503317 non-null  int64
#  6   Time                                         1503200 non-null  object
#  7   1st_Road_Class                               1503317 non-null  int64
#  8   Road_Type                                    1503317 non-null  object
#  9   Speed_limit                                  1503317 non-null  int64
#  10  Junction_Control                             901315 non-null   object
#  11  2nd_Road_Class                               1503317 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1503302 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1503284 non-null  object
#  14  Light_Conditions                             1503317 non-null  object
#  15  Weather_Conditions                           1503191 non-null  object
#  16  Road_Surface_Conditions                      1501362 non-null  object
#  17  Special_Conditions_at_Site                   1503303 non-null  object
#  18  Carriageway_Hazards                          1503289 non-null  object
#  19  Urban_or_Rural_Area                          1503317 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1500404 non-null  object
#  21  verif                                        1503317 non-null  bool
# dtypes: bool(1), int64(9), object(12)
# memory usage: 253.8+ MB

# %%
df1['Junction_Control'].value_counts()
# Out:
# Giveway or uncontrolled     733940
# Automatic traffic signal    155717
# Stop Sign                     9179
# Authorised person             2479
# Name: Junction_Control, dtype: int64

# %%
df1['Junction_Control']=df1['Junction_Control'].fillna('No_Junction')

# %%
df1['Junction_Control'].value_counts()
# Out:
# Giveway or uncontrolled     733940
# No_Junction                 602002
# Automatic traffic signal    155717
# Stop Sign                     9179
# Authorised person             2479
# Name: Junction_Control, dtype: int64

# %%
df1.drop(['verif'],axis=1,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1503317 entries, 0 to 1504149
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1503317 non-null  int64
#  1   Accident_Severity                            1503317 non-null  int64
#  2   Number_of_Vehicles                           1503317 non-null  int64
#  3   Number_of_Casualties                         1503317 non-null  int64
#  4   Date                                         1503317 non-null  object
#  5   Day_of_Week                                  1503317 non-null  int64
#  6   Time                                         1503200 non-null  object
#  7   1st_Road_Class                               1503317 non-null  int64
#  8   Road_Type                                    1503317 non-null  object
#  9   Speed_limit                                  1503317 non-null  int64
#  10  Junction_Control                             1503317 non-null  object
#  11  2nd_Road_Class                               1503317 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1503302 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1503284 non-null  object
#  14  Light_Conditions                             1503317 non-null  object
#  15  Weather_Conditions                           1503191 non-null  object
#  16  Road_Surface_Conditions                      1501362 non-null  object
#  17  Special_Conditions_at_Site                   1503303 non-null  object
#  18  Carriageway_Hazards                          1503289 non-null  object
#  19  Urban_or_Rural_Area                          1503317 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1500404 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 252.3+ MB

# %%
df1['Road_Type'].value_counts()
# Out:
# Single carriageway    1126322
# Dual carriageway       221634
# Roundabout             100454
# One way street          30956
# Slip road               15661
# Unknown                  8290
# Name: Road_Type, dtype: int64

# %%
df1['Light_Conditions'].value_counts()
# Out:
# Daylight: Street light present               1101614
# Darkness: Street lights present and lit       296215
# Darkeness: No street lighting                  82509
# Darkness: Street lighting unknown              16077
# Darkness: Street lights present but unlit       6902
# Name: Light_Conditions, dtype: int64

# %%
df1['Weather_Conditions'].value_counts()
# Out:
# Fine without high winds       1203323
# Raining without high winds     177570
# Other                           33474
# Unknown                         28242
# Raining with high winds         20798
# Fine with high winds            18346
# Snowing without high winds      11295
# Fog or mist                      8185
# Snowing with high winds          1958
# Name: Weather_Conditions, dtype: int64

# %%
df1['verif_NaN']=df1.apply(lambda x:True if pd.isna(x['Time']) or pd.isna(x['Pedestrian_Crossing-Human_Control']) or pd.isna(x['Pedestrian_Crossing-Physical_Facilities']) or pd.isna(x['Weather_Conditions']) or pd.isna(x['Road_Surface_Conditions']) or pd.isna(x['Special_Conditions_at_Site']) or pd.isna(x['Carriageway_Hazards']) or pd.isna(x['Did_Police_Officer_Attend_Scene_of_Accident']) else False, axis=1)
df1.info()

# %%
df1['verif_NaN'].value_counts()
# Out:
# False    1498780
# True        4537
# Name: verif_NaN, dtype: int64

# %%
df1.drop(df1[df1['verif_NaN']==True].index,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1498780 entries, 0 to 1504149
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1498780 non-null  int64
#  1   Accident_Severity                            1498780 non-null  int64
#  2   Number_of_Vehicles                           1498780 non-null  int64
#  3   Number_of_Casualties                         1498780 non-null  int64
#  4   Date                                         1498780 non-null  object
#  5   Day_of_Week                                  1498780 non-null  int64
#  6   Time                                         1498780 non-null  object
#  7   1st_Road_Class                               1498780 non-null  int64
#  8   Road_Type                                    1498780 non-null  object
#  9   Speed_limit                                  1498780 non-null  int64
#  10  Junction_Control                             1498780 non-null  object
#  11  2nd_Road_Class                               1498780 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1498780 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1498780 non-null  object
#  14  Light_Conditions                             1498780 non-null  object
#  15  Weather_Conditions                           1498780 non-null  object
#  16  Road_Surface_Conditions                      1498780 non-null  object
#  17  Special_Conditions_at_Site                   1498780 non-null  object
#  18  Carriageway_Hazards                          1498780 non-null  object
#  19  Urban_or_Rural_Area                          1498780 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1498780 non-null  object
#  21  verif_NaN                                    1498780 non-null  bool
# dtypes: bool(1), int64(9), object(12)
# memory usage: 253.0+ MB

# %%
df1.drop(['verif_NaN'],axis=1,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1498780 entries, 0 to 1504149
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1498780 non-null  int64
#  1   Accident_Severity                            1498780 non-null  int64
#  2   Number_of_Vehicles                           1498780 non-null  int64
#  3   Number_of_Casualties                         1498780 non-null  int64
#  4   Date                                         1498780 non-null  object
#  5   Day_of_Week                                  1498780 non-null  int64
#  6   Time                                         1498780 non-null  object
#  7   1st_Road_Class                               1498780 non-null  int64
#  8   Road_Type                                    1498780 non-null  object
#  9   Speed_limit                                  1498780 non-null  int64
#  10  Junction_Control                             1498780 non-null  object
#  11  2nd_Road_Class                               1498780 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1498780 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1498780 non-null  object
#  14  Light_Conditions                             1498780 non-null  object
#  15  Weather_Conditions                           1498780 non-null  object
#  16  Road_Surface_Conditions                      1498780 non-null  object
#  17  Special_Conditions_at_Site                   1498780 non-null  object
#  18  Carriageway_Hazards                          1498780 non-null  object
#  19  Urban_or_Rural_Area                          1498780 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1498780 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 251.6+ MB

# %%
df1['verif_Unknown']=df1.apply(lambda x:True if x['Road_Type']=='Unknown' or x['Light_Conditions']=='Darkness: Street lighting unknown' or x['Weather_Conditions']=='Unknown' else False, axis=1)
df1['verif_Unknown'].value_counts()
# Out:
# False    1452458
# True       46322
# Name: verif_Unknown, dtype: int64

# %%
df1.drop(df1[df1['verif_Unknown']==True].index,inplace=True)
df1.drop(['verif_Unknown'],axis=1,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1452458 entries, 0 to 1504149
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Police_Force                                 1452458 non-null  int64
#  1   Accident_Severity                            1452458 non-null  int64
#  2   Number_of_Vehicles                           1452458 non-null  int64
#  3   Number_of_Casualties                         1452458 non-null  int64
#  4   Date                                         1452458 non-null  object
#  5   Day_of_Week                                  1452458 non-null  int64
#  6   Time                                         1452458 non-null  object
#  7   1st_Road_Class                               1452458 non-null  int64
#  8   Road_Type                                    1452458 non-null  object
#  9   Speed_limit                                  1452458 non-null  int64
#  10  Junction_Control                             1452458 non-null  object
#  11  2nd_Road_Class                               1452458 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            1452458 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      1452458 non-null  object
#  14  Light_Conditions                             1452458 non-null  object
#  15  Weather_Conditions                           1452458 non-null  object
#  16  Road_Surface_Conditions                      1452458 non-null  object
#  17  Special_Conditions_at_Site                   1452458 non-null  object
#  18  Carriageway_Hazards                          1452458 non-null  object
#  19  Urban_or_Rural_Area                          1452458 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  1452458 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 243.8+ MB

# %%
#df1.to_csv('Dataset_clean.csv')

# %%
#Objectif : mis en place d'un model prédictif sur la sévérité d'un accident

# donnée de sortie (Y) : Accident_Severity

# données sans intérêt : Accident_Index , Local_Authority_(District) , Local_Authority_(Highway) , 1st_Road_Number , Junction_Detail ,
#                        2nd_Road_Number , Year , Location_Easting_OSGR , Location_Northing_OSGR , Longitude , Latitude , 
#                        LSOA_of_Accident_Location

# données d'intérêt (X) : Police_Force , Number_of_Vehicles , Number_of_Casualties , Date , Day_of_Week , Time ,
#                         1st_Road_Class , Road_Type , Speed_limit , Pedestrian_Crossing-Human_Control , Pedestrian_Crossing-Physical_Facilities ,
#                         Light_Conditions , Weather_Conditions , Road_Surface_Conditions , Special_Conditions_at_Site , Carriageway_Hazards ,
#                         Urban_or_Rural_Area , Did_Police_Officer_Attend_Scene_of_Accident , Junction_Control

'''
TODO :  dataset déséquilivré, faire 1ère analyse pour comparer avant/après ré-équilibrage
'''
