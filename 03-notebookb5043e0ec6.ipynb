# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2012_to_2014.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2009_to_2011.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2005_to_2007.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/accident_coords_update.ipynb
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/ukTrafficAADF.csv
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/Areas.shp
# /kaggle/input/2000-16-traffic-flow-england-scotland-wales/Local_Authority_Districts_Dec_2016.geojson

# %%
dataset1=pd.read_csv('/kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2005_to_2007.csv')
#dataset2=pd.read_csv('/kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2009_to_2011.csv')
#dataset3=pd.read_csv('/kaggle/input/2000-16-traffic-flow-england-scotland-wales/accidents_2012_to_2014.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dataset1.info()
#dataset2.info()
#dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570011 entries, 0 to 570010
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_Index                               570011 non-null  object
#  1   Location_Easting_OSGR                        569910 non-null  float64
#  2   Location_Northing_OSGR                       569910 non-null  float64
#  3   Longitude                                    569910 non-null  float64
#  4   Latitude                                     569910 non-null  float64
#  5   Police_Force                                 570011 non-null  int64
#  6   Accident_Severity                            570011 non-null  int64
#  7   Number_of_Vehicles                           570011 non-null  int64
#  8   Number_of_Casualties                         570011 non-null  int64
#  9   Date                                         570011 non-null  object
#  10  Day_of_Week                                  570011 non-null  int64
#  11  Time                                         569944 non-null  object
#  12  Local_Authority_(District)                   570011 non-null  int64
#  13  Local_Authority_(Highway)                    570011 non-null  object
#  14  1st_Road_Class                               570011 non-null  int64
#  15  1st_Road_Number                              570011 non-null  int64
#  16  Road_Type                                    570011 non-null  object
#  17  Speed_limit                                  570011 non-null  int64
#  18  Junction_Detail                              0 non-null       float64
#  19  Junction_Control                             333066 non-null  object
#  20  2nd_Road_Class                               570011 non-null  int64
#  21  2nd_Road_Number                              570011 non-null  int64
#  22  Pedestrian_Crossing-Human_Control            569994 non-null  object
#  23  Pedestrian_Crossing-Physical_Facilities      569977 non-null  object
#  24  Light_Conditions                             570011 non-null  object
#  25  Weather_Conditions                           569991 non-null  object
#  26  Road_Surface_Conditions                      569349 non-null  object
#  27  Special_Conditions_at_Site                   570000 non-null  object
#  28  Carriageway_Hazards                          569988 non-null  object
#  29  Urban_or_Rural_Area                          570011 non-null  int64
#  30  Did_Police_Officer_Attend_Scene_of_Accident  567636 non-null  object
#  31  LSOA_of_Accident_Location                    522500 non-null  object
#  32  Year                                         570011 non-null  int64
# dtypes: float64(5), int64(13), object(15)
# memory usage: 143.5+ MB

# %%
df1=dataset1.drop(['Accident_Index',
                   'Local_Authority_(District)',
                   'Local_Authority_(Highway)',
                   '1st_Road_Number',
                   'Junction_Detail',
                   '2nd_Road_Number',
                   'Year',
                   'Location_Easting_OSGR',
                   'Location_Northing_OSGR',
                   'Longitude',
                   'Latitude',
                   'LSOA_of_Accident_Location'
                  ],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570011 entries, 0 to 570010
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Police_Force                                 570011 non-null  int64
#  1   Accident_Severity                            570011 non-null  int64
#  2   Number_of_Vehicles                           570011 non-null  int64
#  3   Number_of_Casualties                         570011 non-null  int64
#  4   Date                                         570011 non-null  object
#  5   Day_of_Week                                  570011 non-null  int64
#  6   Time                                         569944 non-null  object
#  7   1st_Road_Class                               570011 non-null  int64
#  8   Road_Type                                    570011 non-null  object
#  9   Speed_limit                                  570011 non-null  int64
#  10  Junction_Control                             333066 non-null  object
#  11  2nd_Road_Class                               570011 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            569994 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      569977 non-null  object
#  14  Light_Conditions                             570011 non-null  object
#  15  Weather_Conditions                           569991 non-null  object
#  16  Road_Surface_Conditions                      569349 non-null  object
#  17  Special_Conditions_at_Site                   570000 non-null  object
#  18  Carriageway_Hazards                          569988 non-null  object
#  19  Urban_or_Rural_Area                          570011 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  567636 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 91.3+ MB

# %%
# en faisant la soustraction des 'True' de verif2 et verif3, on obtient le nbr de mesure où 
# il y a 2nd_Road_Class != -1 (donc il y a une route secondaire) mais 
# il n'y a pas de descriptif du control de l'intersection.
#
# De plus, le résultat de cette soustraction est positif donc
# toutes les lignes avec 2nd_Road_Class == -1 correspondent bien à Junction_Control == Null

# %%
#True si il y a une 2nd_Road mais pas de description du control de l'intersection
verif4=df1.apply(lambda x:True if x['2nd_Road_Class'] != -1 and x['Junction_Control']!='Authorised person' and x['Junction_Control']!='Giveway or uncontrolled' and x['Junction_Control']!='Automatic traffic signal' and x['Junction_Control']!='Stop Sign' else False, axis=1)
verif4.value_counts()
# Out:
# False    569453
# dtype: int64

# %%
df1['verif']=df1.apply(lambda x:True if x['2nd_Road_Class'] != -1 and x['Junction_Control']!='Authorised person' and x['Junction_Control']!='Giveway or uncontrolled' and x['Junction_Control']!='Automatic traffic signal' and x['Junction_Control']!='Stop Sign' else False, axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570011 entries, 0 to 570010
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Police_Force                                 570011 non-null  int64
#  1   Accident_Severity                            570011 non-null  int64
#  2   Number_of_Vehicles                           570011 non-null  int64
#  3   Number_of_Casualties                         570011 non-null  int64
#  4   Date                                         570011 non-null  object
#  5   Day_of_Week                                  570011 non-null  int64
#  6   Time                                         569944 non-null  object
#  7   1st_Road_Class                               570011 non-null  int64
#  8   Road_Type                                    570011 non-null  object
#  9   Speed_limit                                  570011 non-null  int64
#  10  Junction_Control                             333066 non-null  object
#  11  2nd_Road_Class                               570011 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            569994 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      569977 non-null  object
#  14  Light_Conditions                             570011 non-null  object
#  15  Weather_Conditions                           569991 non-null  object
#  16  Road_Surface_Conditions                      569349 non-null  object
#  17  Special_Conditions_at_Site                   570000 non-null  object
#  18  Carriageway_Hazards                          569988 non-null  object
#  19  Urban_or_Rural_Area                          570011 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  567636 non-null  object
#  21  verif                                        570011 non-null  bool
# dtypes: bool(1), int64(9), object(12)
# memory usage: 91.9+ MB

# %%
df1['Junction_Control'].value_counts()
# Out:
# Giveway or uncontrolled     271570
# Automatic traffic signal     56121
# Stop Sign                     4320
# Authorised person             1055
# Name: Junction_Control, dtype: int64

# %%
df1.drop(df1[df1['verif']==True].index,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569453 entries, 0 to 570010
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Police_Force                                 569453 non-null  int64
#  1   Accident_Severity                            569453 non-null  int64
#  2   Number_of_Vehicles                           569453 non-null  int64
#  3   Number_of_Casualties                         569453 non-null  int64
#  4   Date                                         569453 non-null  object
#  5   Day_of_Week                                  569453 non-null  int64
#  6   Time                                         569386 non-null  object
#  7   1st_Road_Class                               569453 non-null  int64
#  8   Road_Type                                    569453 non-null  object
#  9   Speed_limit                                  569453 non-null  int64
#  10  Junction_Control                             333066 non-null  object
#  11  2nd_Road_Class                               569453 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            569438 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      569420 non-null  object
#  14  Light_Conditions                             569453 non-null  object
#  15  Weather_Conditions                           569433 non-null  object
#  16  Road_Surface_Conditions                      568793 non-null  object
#  17  Special_Conditions_at_Site                   569443 non-null  object
#  18  Carriageway_Hazards                          569431 non-null  object
#  19  Urban_or_Rural_Area                          569453 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  567087 non-null  object
#  21  verif                                        569453 non-null  bool
# dtypes: bool(1), int64(9), object(12)
# memory usage: 112.2+ MB

# %%
df1['Junction_Control'].value_counts()
# Out:
# Giveway or uncontrolled     271570
# Automatic traffic signal     56121
# Stop Sign                     4320
# Authorised person             1055
# Name: Junction_Control, dtype: int64

# %%
df1['Junction_Control']=df1['Junction_Control'].fillna('No_Junction')

# %%
df1['Junction_Control'].value_counts()
# Out:
# Giveway or uncontrolled     271570
# No_Junction                 236387
# Automatic traffic signal     56121
# Stop Sign                     4320
# Authorised person             1055
# Name: Junction_Control, dtype: int64

# %%
df1.drop(['verif'],axis=1,inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569453 entries, 0 to 570010
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Police_Force                                 569453 non-null  int64
#  1   Accident_Severity                            569453 non-null  int64
#  2   Number_of_Vehicles                           569453 non-null  int64
#  3   Number_of_Casualties                         569453 non-null  int64
#  4   Date                                         569453 non-null  object
#  5   Day_of_Week                                  569453 non-null  int64
#  6   Time                                         569386 non-null  object
#  7   1st_Road_Class                               569453 non-null  int64
#  8   Road_Type                                    569453 non-null  object
#  9   Speed_limit                                  569453 non-null  int64
#  10  Junction_Control                             569453 non-null  object
#  11  2nd_Road_Class                               569453 non-null  int64
#  12  Pedestrian_Crossing-Human_Control            569438 non-null  object
#  13  Pedestrian_Crossing-Physical_Facilities      569420 non-null  object
#  14  Light_Conditions                             569453 non-null  object
#  15  Weather_Conditions                           569433 non-null  object
#  16  Road_Surface_Conditions                      568793 non-null  object
#  17  Special_Conditions_at_Site                   569443 non-null  object
#  18  Carriageway_Hazards                          569431 non-null  object
#  19  Urban_or_Rural_Area                          569453 non-null  int64
#  20  Did_Police_Officer_Attend_Scene_of_Accident  567087 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 111.7+ MB

# %%
df1['Road_Type'].value_counts()
# Out:
# Single carriageway    423011
# Dual carriageway       87194
# Roundabout             36630
# One way street         12423
# Slip road               5931
# Unknown                 4264
# Name: Road_Type, dtype: int64

# %%
df1['Light_Conditions'].value_counts()
# Out:
# Daylight: Street light present               413883
# Darkness: Street lights present and lit      114323
# Darkeness: No street lighting                 34169
# Darkness: Street lighting unknown              4616
# Darkness: Street lights present but unlit      2462
# Name: Light_Conditions, dtype: int64

# %%
df1['Weather_Conditions'].value_counts()
# Out:
# Fine without high winds       453672
# Raining without high winds     68564
# Other                          13397
# Unknown                        11328
# Raining with high winds         8030
# Fine with high winds            7539
# Fog or mist                     3377
# Snowing without high winds      2980
# Snowing with high winds          546
# Name: Weather_Conditions, dtype: int64

# %%
#df1.to_excel('Dataset1_v02.xls')

# %%
#Objectif : mis en place d'un model prédictif sur la sévérité d'un accident

# donnée de sortie (Y) : Accident_Severity

# données sans intérêt : Accident_Index , Local_Authority_(District) , Local_Authority_(Highway) , 1st_Road_Number , Junction_Detail ,
#                        2nd_Road_Number , Year , Location_Easting_OSGR , Location_Northing_OSGR , Longitude , Latitude , 
#                        LSOA_of_Accident_Location

# données d'intérêt (X) : Police_Force , Number_of_Vehicles , Number_of_Casualties , Date , Day_of_Week , Time ,
#                         1st_Road_Class , Road_Type , Speed_limit , Pedestrian_Crossing-Human_Control , Pedestrian_Crossing-Physical_Facilities ,
#                         Light_Conditions , Weather_Conditions , Road_Surface_Conditions , Special_Conditions_at_Site , Carriageway_Hazards ,
#                         Urban_or_Rural_Area , Did_Police_Officer_Attend_Scene_of_Accident , Junction_Control

'''
TODO :  _ count() les lignes dont 1 attribut est renseigné 'unknown'
        - gestion des valeurs Null
'''
